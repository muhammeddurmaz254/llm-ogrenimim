# %%
import os
from dotenv import load_dotenv
from google import genai
from bs4 import BeautifulSoup
import requests
from scraper import fetch_website_contents, fetch_website_links

# %%
ed = fetch_website_contents("https://edwarddonner.com")
print(ed)
# Out:
# Home - Edward Donner
#
# Skip to content
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Well, hi there.
# I’m Ed. I like writing code and experimenting with LLMs, and hopefully you’re here because you do too. I also enjoy amateur electronic music production (
# very
# amateur) and losing myself in
# Hacker News
# , nodding my head sagely to things I only half understand.
# I’m the co-founder and CTO of AI startup
# Nebula.io
# . I was previously founder and CEO of AI startup untapt,
# acquired in 2021
# , and a Managing Director at JPMorgan.
# I will happily drone on for hours about LLMs to anyone in my vicinity. My friends got fed up with my impromptu lectures, and convinced me to make some Udemy courses. To my total joy (and shock) they’ve become best-selling, top-rated courses, with 900,000 enrollments across 194 countries. The
# full curriculum is here
# . If you’re visiting from one of my courses – I’m super grateful!
# For more on me and my courses, please
# chat with me and my Digital Avatar here
# .
# February 17, 2026
# AI Coder: Vibe Coder to Agentic Engineer – RESOURCES
# January 4, 2026
# AI Builder with n8n – Create Agents and Voice Agents – RESOURCES
# September 15, 2025
# AI Engineering MLOps Track – Deploy AI to Production – RESOURCES
# May 28, 2025
# Which order to take the AI courses?
# Navigation
# Avatar
# Curriculum
# Proficiency
# C4
# Outsmart
# An arena that pits LLMs against each other in a battle of diplomacy and deviousness
# About
# Posts
# Get in touch
# ed [at] edwarddonner [dot] com
# www.edwarddonner.com
# Follow me
# LinkedIn
# Twitter
# Facebook

# %%
#system prompt is the instruction to the assistant on how to summarize the content of a website
system_prompt = """You are an assistant that summarizes the content of a website.
You will be given the content of a website, and you will summarize it in a few sentences. 
ignore any content that is not relevant to the main topic of the website.
Respond in markdown."""

#user prompt is the content of the website that will be summarized
user_prompt= """ 
Here is the content of a website:
Provide a short summary of the content in a few sentences.
"""

# %%
def summarize_website_content(system_prompt, user_prompt, url):

    client = genai.Client()
    url_content = fetch_website_contents(url)

    config = genai.types.GenerateContentConfig(
    system_instruction=system_prompt
    )

    response = client.models.generate_content(
        model="gemini-3.6-flash",
        config=config,
        contents =f"{user_prompt}\n{url_content}"
        )

    print(response.text)

# %%
summarize_website_content(system_prompt, user_prompt, url="https://www.haberturk.com/ozel-icerikler/murat-bardakci/3904745-eyym-i-bhur")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Bu yazı, Murat Bardakçı'nın yaz mevsiminin en sıcak günlerini ifade eden **"eyyâm-ı bâhur"** kavramını ve bu terimin kökenini ele aldığı bir köşe yazısıdır.
#
# Yazar, bu ifadenin son yıllarda sosyal medyada cehaletten kaynaklı ideolojik tartışmalara konu edildiğini hatırlatmakta; terimin asıl kaynağının ise antik çağlara, Büyük Köpek Takımyıldızı'ndaki Sirius (Akyıldız) yıldızının Temmuz sonunda doğuşuyla başlayan aşırı sıcaklar dönemine dayandığını açıklamaktadır.
